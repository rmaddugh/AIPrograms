# %%
! pip install torch torchvision
! pip install pillow
! pip install transformers tokenizers accelerate
# Out:
# Collecting torch
#   Using cached torch-2.10.0-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Collecting torchvision
#   Using cached torchvision-0.25.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.24.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from torch) (4.15.0)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from torch) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch)
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from torch) (82.0.0)
# Collecting numpy (from torchvision)
#   Using cached numpy-2.4.2-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Using cached pillow-12.1.1-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from jinja2->torch) (3.0.3)
# Using cached torch-2.10.0-cp312-cp312-win_amd64.whl (113.8 MB)
# Using cached torchvision-0.25.0-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached pillow-12.1.1-cp312-cp312-win_amd64.whl (7.0 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached filelock-3.24.2-py3-none-any.whl (24 kB)
# Using cached numpy-2.4.2-cp312-cp312-win_amd64.whl (12.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, pillow, numpy, networkx, fsspec, filelock, torch, torchvision
# Successfully installed filelock-3.24.2 fsspec-2026.2.0 mpmath-1.3.0 networkx-3.6.1 numpy-2.4.2 pillow-12.1.1 sympy-1.14.0 torch-2.10.0 torchvision-0.25.0
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pillow in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (12.1.1)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting transformers
#   Using cached transformers-5.2.0-py3-none-any.whl.metadata (32 kB)
# Collecting tokenizers
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting accelerate
#   Using cached accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Collecting huggingface-hub<2.0,>=1.3.0 (from transformers)
#   Using cached huggingface_hub-1.4.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from transformers) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from transformers) (6.0.3)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2026.1.15-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting typer-slim (from transformers)
#   Using cached typer_slim-0.24.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: psutil in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: torch>=2.0.0 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from accelerate) (2.10.0)
# Requirement already satisfied: filelock in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (3.24.2)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.0)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Collecting shellingham (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: setuptools in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from torch>=2.0.0->accelerate) (82.0.0)
# Requirement already satisfied: colorama in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Collecting typer>=0.24.0 (from typer-slim->transformers)
#   Using cached typer-0.24.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Collecting click>=8.2.1 (from typer>=0.24.0->typer-slim->transformers)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting rich>=12.3.0 (from typer>=0.24.0->typer-slim->transformers)
#   Using cached rich-14.3.2-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer>=0.24.0->typer-slim->transformers)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->transformers)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached transformers-5.2.0-py3-none-any.whl (10.4 MB)
# Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached accelerate-1.12.0-py3-none-any.whl (380 kB)
# Using cached huggingface_hub-1.4.1-py3-none-any.whl (553 kB)
# Using cached regex-2026.1.15-cp312-cp312-win_amd64.whl (277 kB)
# Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached typer_slim-0.24.0-py3-none-any.whl (3.4 kB)
# Using cached hf_xet-1.2.0-cp37-abi3-win_amd64.whl (2.9 MB)
# Using cached typer-0.24.0-py3-none-any.whl (56 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached rich-14.3.2-py3-none-any.whl (309 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: tqdm, shellingham, safetensors, regex, mdurl, hf-xet, click, annotated-doc, markdown-it-py, rich, typer, typer-slim, huggingface-hub, tokenizers, accelerate, transformers
# Successfully installed accelerate-1.12.0 annotated-doc-0.0.4 click-8.3.1 hf-xet-1.2.0 huggingface-hub-1.4.1 markdown-it-py-4.0.0 mdurl-0.1.2 regex-2026.1.15 rich-14.3.2 safetensors-0.7.0 shellingham-1.5.4 tokenizers-0.22.2 tqdm-4.67.3 transformers-5.2.0 typer-0.24.0 typer-slim-0.24.0
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
from transformers import pipeline
from PIL import Image

# %%
narrator = pipeline(
    task="text-to-speech",
    model="suno/bark-small",
)
# Out:
# Loading weights:   0%|          | 0/542 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie fine_acoustics.input_embeds_layers.1.weight to fine_acoustics.lm_heads.0.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie fine_acoustics.input_embeds_layers.2.weight to fine_acoustics.lm_heads.1.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie fine_acoustics.input_embeds_layers.3.weight to fine_acoustics.lm_heads.2.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie fine_acoustics.input_embeds_layers.4.weight to fine_acoustics.lm_heads.3.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie fine_acoustics.input_embeds_layers.5.weight to fine_acoustics.lm_heads.4.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie fine_acoustics.input_embeds_layers.6.weight to fine_acoustics.lm_heads.5.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie fine_acoustics.input_embeds_layers.7.weight to fine_acoustics.lm_heads.6.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
! pip install google-genai
# Out:
# Collecting google-genai
#   Using cached google_genai-1.63.0-py3-none-any.whl.metadata (53 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from google-genai) (4.12.1)
# Collecting google-auth<3.0.0,>=2.47.0 (from google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Using cached google_auth-2.48.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from google-genai) (0.28.1)
# Collecting pydantic<3.0.0,>=2.9.0 (from google-genai)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from google-genai) (2.32.5)
# Collecting tenacity<9.2.0,>=8.2.3 (from google-genai)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting websockets<15.1.0,>=13.0.0 (from google-genai)
#   Using cached websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from google-genai) (4.15.0)
# Collecting distro<2,>=1.7.0 (from google-genai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting sniffio (from google-genai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: idna>=2.8 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Using cached cryptography-46.0.5-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: certifi in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.9.0->google-genai)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.9.0->google-genai)
#   Using cached pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.9.0->google-genai)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.0.0)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Using cached pyasn1-0.6.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: pycparser in d:\tejas\ucinnovation\2026\llmlabs\gemini-speech-exp\.env_gemini-speech\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (3.0)
# Using cached google_genai-1.63.0-py3-none-any.whl (724 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached google_auth-2.48.0-py3-none-any.whl (236 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Using cached websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached cryptography-46.0.5-cp311-abi3-win_amd64.whl (3.5 MB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached pyasn1-0.6.2-py3-none-any.whl (83 kB)
# Installing collected packages: websockets, typing-inspection, tenacity, sniffio, pydantic-core, pyasn1, distro, annotated-types, rsa, pydantic, pyasn1-modules, cryptography, google-auth, google-genai
# Successfully installed annotated-types-0.7.0 cryptography-46.0.5 distro-1.9.0 google-auth-2.48.0 google-genai-1.63.0 pyasn1-0.6.2 pyasn1-modules-0.4.2 pydantic-2.12.5 pydantic-core-2.41.5 rsa-4.9.1 sniffio-1.3.1 tenacity-9.1.4 typing-inspection-0.4.2 websockets-15.0.1
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google import genai

f = open("keys/.gemini.txt")
key = f.read()

client = genai.Client(api_key=key)

# %%
from google import genai
from google.genai import types

with open('images/image_astro.JPG', 'rb') as f:
  image_bytes = f.read()

context = [
    types.Part.from_bytes(
        data=image_bytes,
        mime_type='image/jpeg',
    ),
]

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=context,
)

print(response.text)
# Out:
# This image depicts a surreal and whimsical scene featuring an astronaut sitting in the driver's seat of a white delivery-style truck.
#
# **Main Subject:**
# In the center of the frame, an astronaut is clad in a full white space suit, complete with a large, rounded helmet and a dark visor that hides their face. The astronaut’s gloved hands are positioned on a black steering wheel, as if they are navigating the vehicle through a terrestrial landscape.
#
# **The Vehicle:**
# The vehicle is a white, boxy truck reminiscent of a mail carrier or a small airport shuttle. It features several distinct details:
# *   A row of round red and orange lights across the top of the front windshield area.
# *   Two vibrant blue stripes running horizontally along the side.
# *   Standard headlights and a large, dark gray rectangular panel on the front hood.
# *   Large black side mirrors and black tires.
#
# **Setting and Background:**
# The scene is set outdoors amidst lush greenery.
# *   In the lower-left foreground, several bright orange and yellow flowers are in bloom, partially obscured by soft-focus foliage.
# *   To the right of the truck, there are more green bushes and trees.
# *   The sky above is a deep, saturated blue, and dark tree branches with leaves hang down from the top left corner, framing the top of the vehicle.
#
# **Style and Atmosphere:**
# The image has a digital art or AI-generated aesthetic, characterized by high-contrast lighting, saturated colors, and a slightly soft, painterly quality in the details of the plants. The juxtaposition of a high-tech space traveler in a mundane, everyday vehicle creates a playful, dreamlike, and surreal atmosphere.

# %%
text = response.text
text
# Out:
# "This image depicts a surreal and whimsical scene featuring an astronaut sitting in the driver's seat of a white delivery-style truck.\n\n**Main Subject:**\nIn the center of the frame, an astronaut is clad in a full white space suit, complete with a large, rounded helmet and a dark visor that hides their face. The astronaut’s gloved hands are positioned on a black steering wheel, as if they are navigating the vehicle through a terrestrial landscape.\n\n**The Vehicle:**\nThe vehicle is a white, boxy truck reminiscent of a mail carrier or a small airport shuttle. It features several distinct details:\n*   A row of round red and orange lights across the top of the front windshield area.\n*   Two vibrant blue stripes running horizontally along the side.\n*   Standard headlights and a large, dark gray rectangular panel on the front hood.\n*   Large black side mirrors and black tires.\n\n**Setting and Background:**\nThe scene is set outdoors amidst lush greenery. \n*   In the lower-left foreground, several bright orange and yellow flowers are in bloom, partially obscured by soft-focus foliage.\n*   To the right of the truck, there are more green bushes and trees.\n*   The sky above is a deep, saturated blue, and dark tree branches with leaves hang down from the top left corner, framing the top of the vehicle.\n\n**Style and Atmosphere:**\nThe image has a digital art or AI-generated aesthetic, characterized by high-contrast lighting, saturated colors, and a slightly soft, painterly quality in the details of the plants. The juxtaposition of a high-tech space traveler in a mundane, everyday vehicle creates a playful, dreamlike, and surreal atmosphere."

# %%
narrated_text = narrator(text)
# Out:
# Passing `generation_config` together with generation-related arguments=({'min_eos_p', 'return_dict_in_generate'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Both `max_new_tokens` (=768) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Passing `generation_config` together with generation-related arguments=({'return_dict_in_generate', 'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=60) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=28) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(narrated_text["sampling_rate"])
# Out:
# 24000

# %%
from IPython.display import Audio as IPythonAudio

IPythonAudio(
    narrated_text["audio"],
    rate=narrated_text["sampling_rate"]
)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
